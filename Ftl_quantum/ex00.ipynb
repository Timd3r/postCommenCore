# %%
# !pip install qiskit qiskit-aer matplotlib

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
from qiskit import transpile

# %%
# 1. Create a Quantum Circuit with 1 qubit and 1 classical bit
#The first 1 (Qubits): This tells the computer to reserve one quantum bit. This is the "spinning coin". It is the bit that will undergo superposition.
#The second 1 (Classical Bits): This tells the computer to reserve one classical bit (a standard 0 or 1).
qc = QuantumCircuit(1, 1)

# %%
# 2. the Hadamard Gate. It tells the computer: "Take qubit number 0 and make it spin (superposition).
qc.h(0)

# %%
#3. Measure this tells the computer: "Look at the qubit and save what you see into a normal digital bit."
# The first 0 is which qubit you want to measure
# the second 0 is where you want to save this data (classical bit)
qc.measure(0, 0)

# %%
# 4. Draw the circuit so you can see it
print("Your Circuit Diagram:")
display(qc.draw(output='mpl'))
# Out:
# Your Circuit Diagram:

# %%
# 1. Choose the simulator (the "fake" quantum computer)
backend = Aer.get_backend('qasm_simulator')

# %%
# 2. Run the circuit 500 times as requested by the PDF
# We use 'transpile' to make sure the math is optimized for the simulator
job = backend.run(transpile(qc, backend), shots=500)

# %%
# 3. Grab the results
result = job.result()
counts = result.get_counts()

# %%
# 4. Show the final graph!
print("Measurement Results (500 shots):", counts)
plot_histogram(counts)
# Out:
# Measurement Results (500 shots): {'0': 255, '1': 245}
